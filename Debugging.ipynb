# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from __future__ import absolute_import, division, print_function
import sklearn
from sklearn.model_selection import train_test_split

# %%
Data=pd.read_csv('C:/Users/muneeba/Desktop/THESIS/DataDistributionPCA.csv')
Dataval=Data.iloc[:,4:68]
Dataval=Dataval[:64]
ylabel=Data.iloc[:,0:64]
TestData=pd.read_csv('C:/Users/muneeba/Desktop/THESIS/Testing.csv')
Testval=TestData.iloc[:,0:64]
Testval=Testval[:64]
ytest=TestData.iloc[:,0:64]

# %%
def multilayer_dnn(X):
    fc1=tf.layers.dense(X,14,activation=tf.nn.relu)
    fc2=tf.layers.dense(fc1,3,activation=tf.nn.relu)
    out=tf.layers.dense(fc2,64,activation=None)
    return out,fc2,fc1

# %%
X=tf.placeholder(tf.float32, shape=[None, 64])
y=tf.placeholder(tf.float32, shape=[None, 64])

# %%
logits, fc1, fc2=multilayer_dnn(X)

 
xentropy=tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits,labels=y)
loss=tf.reduce_mean(xentropy)
optimizer=tf.train.AdamOptimizer(0.001)
training_op=optimizer.minimize(loss)

# %%
 
correct=tf.equal(tf.argmax(logits,1), tf.argmax(y,1))
accuracy=tf.reduce_mean(tf.cast(correct, tf.float32))
tf.summary.scalar('accuracy', accuracy)
    
merged = tf.summary.merge_all()

 
init = tf.global_variables_initializer()
n_epochs = 20
batch_size = 10
 
x1=Dataval.iloc[:,0:64]

# %%
 
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):

        num_iterations =  5
        for iteration in range(num_iterations):
            X_batch, y_batch = x1, ylabel
            _, loss_eval, fc1_eval, fc2_eval, logits_eval = \
               sess.run([training_op, loss, fc1, fc2, logits],
                     feed_dict={X: X_batch, y: y_batch})
                 # Calculate and print the accuracy for every training batch
             
            if iteration == num_iterations - 1:
                print("Layer            :  Mean     Standard Deviation")
                print("Fully connected 1: ", fc1_eval.mean(), fc1_eval.std())
                print("Fully connected 2: ", fc2_eval.mean(), fc2_eval.std())

           
            acc_train = accuracy.eval(
                feed_dict={X: X_batch, y: y_batch})
            acc_test = accuracy.eval(
                feed_dict={X: Testval, y: ylabel})

            print(epoch, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
            print()
# Out:
# 0 Train accuracy: 0.71875 Test accuracy: 0.546875
#
# 0 Train accuracy: 0.84375 Test accuracy: 0.6875
#
# 0 Train accuracy: 0.84375 Test accuracy: 0.703125
#
# 0 Train accuracy: 0.84375 Test accuracy: 0.703125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.00785669 0.0177863
# Fully connected 2:  0.0157921 0.036244
# 0 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 1 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 1 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 1 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 1 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0172077 0.0344869
# Fully connected 2:  0.0166563 0.0376631
# 1 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 2 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 2 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 2 Train accuracy: 0.84375 Test accuracy: 0.71875
#
# 2 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0268471 0.0513516
# Fully connected 2:  0.0184049 0.0405516
# 2 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 3 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 3 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 3 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 3 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0356702 0.0664466
# Fully connected 2:  0.0208914 0.0443067
# 3 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 4 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 4 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 4 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 4 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0453004 0.0824983
# Fully connected 2:  0.0237722 0.0491168
# 4 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 5 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 5 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 5 Train accuracy: 0.84375 Test accuracy: 0.734375
#
# 5 Train accuracy: 0.84375 Test accuracy: 0.75
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0554431 0.0998638
# Fully connected 2:  0.0270125 0.0546161
# 5 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 6 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 6 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 6 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 6 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0662258 0.118593
# Fully connected 2:  0.0305508 0.060766
# 6 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 7 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 7 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 7 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 7 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0775659 0.13843
# Fully connected 2:  0.0344194 0.0674735
# 7 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 8 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 8 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 8 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 8 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.0893778 0.159227
# Fully connected 2:  0.0386893 0.0745679
# 8 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 9 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 9 Train accuracy: 0.84375 Test accuracy: 0.765625
#
# 9 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 9 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.102149 0.182459
# Fully connected 2:  0.0433975 0.0819332
# 9 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 10 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 10 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 10 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 10 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.115936 0.207852
# Fully connected 2:  0.0485035 0.0895791
# 10 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 11 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 11 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 11 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 11 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.130595 0.23487
# Fully connected 2:  0.0539838 0.0975664
# 11 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 12 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 12 Train accuracy: 0.84375 Test accuracy: 0.78125
#
# 12 Train accuracy: 0.84375 Test accuracy: 0.796875
#
# 12 Train accuracy: 0.84375 Test accuracy: 0.796875
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.146165 0.263959
# Fully connected 2:  0.0598484 0.10587
# 12 Train accuracy: 0.84375 Test accuracy: 0.796875
#
# 13 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 13 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 13 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 13 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.162703 0.294904
# Fully connected 2:  0.0659886 0.114534
# 13 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 14 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 14 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 14 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 14 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.180211 0.327739
# Fully connected 2:  0.0723941 0.12355
# 14 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 15 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 15 Train accuracy: 0.84375 Test accuracy: 0.8125
#
# 15 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 15 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.198714 0.36252
# Fully connected 2:  0.0790983 0.132875
# 15 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 16 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 16 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 16 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 16 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.218166 0.399103
# Fully connected 2:  0.0860414 0.142516
# 16 Train accuracy: 0.84375 Test accuracy: 0.828125
#
# 17 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 17 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 17 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 17 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.238847 0.438114
# Fully connected 2:  0.0932736 0.152415
# 17 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 18 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 18 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 18 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 18 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.260543 0.479029
# Fully connected 2:  0.100686 0.162621
# 18 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 19 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 19 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 19 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# 19 Train accuracy: 0.84375 Test accuracy: 0.84375
#
# Layer            :  Mean     Standard Deviation
# Fully connected 1:  0.283219 0.52179
# Fully connected 2:  0.108255 0.173123
# 19 Train accuracy: 0.84375 Test accuracy: 0.84375
